# %% [markdown]
# # 4.4. The Stack Abstract Data Type

# %% [markdown]
# ![stack.JPG](attachment:stack.JPG)

# %% [markdown]
# ![operations.JPG](attachment:operations.JPG)

# %% [markdown]
# # 4.5. Implementing a Stack in Python
# https://runestone.academy/runestone/books/published/pythonds3/BasicDS/ImplementingaStackinPython.html

# %%
class Stack:
    """Stack implementation as a list"""
    
    def __init__(self):
        """Create new stack as an empty list"""
        self._items = []
        
    def is_empty(self):
        """Check if the stack is empty"""
        return not bool(self._items)
    
    def push(self, item):
        """Add an item to the stack"""
        self._items.append(item)
        
    def pop(self):
        """Remove an item from the stack"""
        return self._items.pop()
    
    def peek(self):
        """Get the value of the top item in the stack"""
        return self._items[-1]
    
    def size(self):
        """Get the number of items in the stack"""
        return len(self._items)

# %%
print(Stack)
# Out:
# <class '__main__.Stack'>

# %%
pip install pythonds3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pythonds3.basic import Stack

s = Stack()

# %%
print(s)

# %%
print(s.is_empty())
# Out:
# True

# %%
s.push(4)

# %%
s.push("cat")

# %%
print(s.peek())
# Out:
# cat

# %%
s.push(True)

# %%
print(s.size())
# Out:
# 3

# %%
print(s.is_empty())
# Out:
# False

# %%
s.push(8.4)

# %%
print(s.pop())
# Out:
# 8.4

# %%
print(s.pop())
# Out:
# True

# %%
print(s.size())
# Out:
# 2

# %%
m = Stack()
m.push("x")
m.push("y")
m.push("z")

while not m.is_empty():
    m.pop()
    m.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-10f6b45c6fdd> in <module>
#       6 while not m.is_empty():
#       7     m.pop()
# ----> 8     m.pop()
#
# C:\ProgramData\Miniconda3\lib\site-packages\pythonds3\basic\stack.py in pop(self)
#      25     def pop(self):
#      26         """Remove an item from the stack"""
# ---> 27         return self._items.pop()
#      28
#      29     def peek(self):
#
# IndexError: pop from empty list

# %% [markdown]
# ![stack.JPG](attachment:stack.JPG)

# %%
pip install test
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Could not find a version that satisfies the requirement test (from versions: none)
# ERROR: No matching distribution found for test

# %%
from test import testEqual
from pythonds.basic.stack import Stack

def revstring(mystr):
    # traverse through stack
    myStack =Stack()
    for ch in mystr: 
        myStack.push(ch)
    revstr = ''
    while not myStack.isEmpty():
        revstr = revstr + myStack.pop()
        
    return revstr

testEqual(revstring('apple'), 'elppa')
testEqual(revstring('x'), 'x')
testEqual(revstring('1234567890'), '0987654321')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-37fde9cb7d28> in <module>
# ----> 1 from test import testEqual
#       2 from pythonds.basic.stack import Stack
#       3
#
# ImportError: cannot import name 'testEqual' from 'test' (C:\ProgramData\Miniconda3\lib\test\__init__.py)

# %% [markdown]
# # 4.6 Simple Balanced Paretheses

# %% [markdown]
# ![parentesis.JPG](attachment:parentesis.JPG)

# %%
from pythonds3.basic import Stack

def par_checker(symbol_string):
    s = Stack()
    for symbol in symbol_string:
        if symbol == "(":
            s.push(symbol)
        else:
            if s.is_empty():
                return False
            else:
                s.pop()
    return s.is_empty()

# %%
# Examples of balanced parethesis

# %%
print(par_checker("((()))"))
# Out:
# True

# %%
print(par_checker("((()()))"))
# Out:
# True

# %%
# Examples of unbalanced parethesis

# %%
print(par_checker("(()"))
# Out:
# False

# %%
print(par_checker(")("))
# Out:
# False

# %%
from pythonds3.basic import Stack


def balance_checker(symbol_string):
    s = Stack()
    for symbol in symbol_string:
        if symbol in "([{":
            s.push(symbol)
        else:
            if s.is_empty():
                return False
            else:
                if not matches(s.pop(), symbol):
                    return False

    return s.is_empty()

def matches(sym_left, sym_right):
    all_lefts = "([{"
    all_rights = ")]}"
    return all_lefts.index(sym_left) == all_rights.index(sym_right)

# %%
print(balance_checker('{({([][])}())}'))
print(balance_checker('[{()]'))
# Out:
# True
# False
